# %%
from google.cloud import bigquery
import folium

# %%
# Initialize BigQuery client
client = bigquery.Client()

# Bring in all data:
# ------------------

# Create function to grab each table and return a df
def get_data(table_name):
    query = f"select * from `bigquery-public-data.thelook_ecommerce.{table_name}`"
    return client.query(query).to_dataframe()

# Assign each df to a variable
table_names = ['distribution_centers', 'users', 'orders', 'order_items', 'inventory_items']
for i in range(len(table_names)):
    globals()[table_names[i]] = get_data(table_names[i])

# %%
# Find out if two items in an order were shipped out separately
import duckdb

query_distinct_shipments = """
select
    order_id
    , count(distinct shipped_at) as distinct_ship_times
from order_items
group by 1
having count(distinct shipped_at) > 1
order by 2 desc
"""

result = duckdb.query(query_distinct_shipments).df()
result # Answer: No, all items in an order were shipped out at the same time
# Out:
# Empty DataFrame
# Columns: [order_id, distinct_ship_times]
# Index: []

# %%
# Find out how many items are in each order and their counts
query_items_per_order = """
select
    order_id
    , count(id) as num_items
from order_items
group by 1
order by 2 desc
"""
duckdb.query(query_items_per_order).df() # Number of items per order ranges from 1 to 4
# Out:
#         order_id  num_items
# 0          25437          4
# 1          36575          4
# 2          68082          4
# 3          90181          4
# 4          48513          4
# ...          ...        ...
# 124535     44135          1
# 124536     85546          1
# 124537     17604          1
# 124538    104113          1
# 124539     91969          1
#
# [124540 rows x 2 columns]

# %%
# Preview order_id in order_items table
query_order_id_items = """
select *
from order_items
where order_id = 47598
"""
duckdb.query(query_order_id_items).df() # Extra validation that all the items in order 47598 were shipped at the same time
# Out:
#       id  order_id  user_id  product_id  inventory_item_id      status  \
# 0  68896     47598    38234       25331             186258  Processing
#
#                  created_at shipped_at delivered_at returned_at  sale_price
# 0 2024-03-30 12:05:39+00:00        NaT          NaT         NaT        8.99

# %%
# Create dataset by joining tables

order_details = (
    order_items
    .merge(inventory_items, how='left', left_on='inventory_item_id', right_on='id', suffixes=('_order_items', '_inventory'))
    .merge(distribution_centers, how='left', left_on='product_distribution_center_id', right_on='id')
    .merge(users, how='left', left_on='user_id', right_on='id', suffixes=('', '_user'))
)

order_details.rename(columns={'id': 'id_dist_center', 'name': 'name_dist_center', 'latitude': 'latitude_dist_center', 'longitude': 'longitude_dist_center'}, inplace=True)
print(order_details.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180466 entries, 0 to 180465
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id_order_items                  180466 non-null  Int64
#  1   order_id                        180466 non-null  Int64
#  2   user_id                         180466 non-null  Int64
#  3   product_id_order_items          180466 non-null  Int64
#  4   inventory_item_id               180466 non-null  Int64
#  5   status                          180466 non-null  object
#  6   created_at_order_items          180466 non-null  datetime64[ns, UTC]
#  7   shipped_at                      117625 non-null  datetime64[ns, UTC]
#  8   delivered_at                    63446 non-null   datetime64[ns, UTC]
#  9   returned_at                     17810 non-null   datetime64[ns, UTC]
#  10  sale_price                      180466 non-null  float64
#  11  id_inventory                    180466 non-null  Int64
#  12  product_id_inventory            180466 non-null  Int64
#  13  created_at_inventory            180466 non-null  datetime64[ns, UTC]
#  14  sold_at                         0 non-null       datetime64[ns, UTC]
#  15  cost                            180466 non-null  float64
#  16  product_category                180466 non-null  object
#  17  product_name                    180466 non-null  object
#  18  product_brand                   180466 non-null  object
#  19  product_retail_price            180466 non-null  float64
#  20  product_department              180466 non-null  object
#  21  product_sku                     180466 non-null  object
#  22  product_distribution_center_id  180466 non-null  Int64
#  23  id_dist_center                  180466 non-null  Int64
#  24  name_dist_center                180466 non-null  object
#  25  latitude_dist_center            180466 non-null  float64
#  26  longitude_dist_center           180466 non-null  float64
#  27  distribution_center_geom        180466 non-null  object
#  28  id_user                         180466 non-null  Int64
#  29  first_name                      180466 non-null  object
#  30  last_name                       180466 non-null  object
#  31  email                           180466 non-null  object
#  32  age                             180466 non-null  Int64
#  33  gender                          180466 non-null  object
#  34  state                           180466 non-null  object
#  35  street_address                  180466 non-null  object
#  36  postal_code                     180466 non-null  object
#  37  city                            180466 non-null  object
#  38  country                         180466 non-null  object
#  39  latitude_user                   180466 non-null  float64
#  40  longitude_user                  180466 non-null  float64
#  41  traffic_source                  180466 non-null  object
#  42  created_at                      180466 non-null  datetime64[ns, UTC]
#  43  user_geom                       180466 non-null  object
# dtypes: Int64(11), datetime64[ns, UTC](7), float64(7), object(19)
# memory usage: 63.9+ MB
# None

# %%
# Filter for only shipped orders
shipped_orders = order_details[order_details['status'] == 'Shipped']

# Select only relevant columns
relevant_data = shipped_orders[[
    'distribution_center_geom',
    'latitude_dist_center',
    'longitude_dist_center',
    'user_geom',
    'latitude_user',
    'longitude_user',
    'first_name', 'last_name', 
    'city', 'state',
    'name_dist_center',
    'order_id'
]]

relevant_data.reset_index(inplace=True)
relevant_data
# Out:
#         index distribution_center_geom  latitude_dist_center  \
# 0           2  POINT(-89.9711 35.1174)               35.1174
# 1           3  POINT(-89.9711 35.1174)               35.1174
# 2           4  POINT(-89.9711 35.1174)               35.1174
# 3          15  POINT(-88.0431 30.6944)               30.6944
# 4          16  POINT(-88.0431 30.6944)               30.6944
# ...       ...                      ...                   ...
# 54174  180461    POINT(-90.0667 29.95)               29.9500
# 54175  180462    POINT(-90.0667 29.95)               29.9500
# 54176  180463    POINT(-90.0667 29.95)               29.9500
# 54177  180464    POINT(-90.0667 29.95)               29.9500
# 54178  180465    POINT(-90.0667 29.95)               29.9500
#
#        longitude_dist_center                         user_geom  latitude_user  \
# 0                   -89.9711    POINT(2.898221046 42.70234107)      42.702341
# 1                   -89.9711   POINT(-122.9912099 45.32309358)      45.323094
# 2                   -89.9711    POINT(-4.80601686 39.95638658)      39.956387
# 3                   -88.0431  POINT(-59.53483513 -4.957320329)      -4.957320
# 4                   -88.0431   POINT(-47.9225723 -15.82675402)     -15.826754
# ...                      ...                               ...            ...
# 54174               -90.0667    POINT(2.360737029 48.87612795)      48.876128
# 54175               -90.0667  POINT(-40.04733317 -4.343551853)      -4.343552
# 54176               -90.0667   POINT(-117.2639164 33.62108805)      33.621088
# 54177               -90.0667    POINT(-83.9534186 43.60063776)      43.600638
# 54178               -90.0667    POINT(104.5482719 30.71428531)      30.714285
#
#        longitude_user first_name last_name                     city  \
# 0            2.898221      Debra     Wiley                Perpignan
# 1         -122.991210   Michelle     Perez                  Newberg
# 2           -4.806017    Caitlin    Foster     Talavera de la Reina
# 3          -59.534835    Kenneth   Sweeney                     null
# 4          -47.922572     Martin     Perez                 Brasília
# ...               ...        ...       ...                      ...
# 54174        2.360737     Joseph  Thompson                    Paris
# 54175      -40.047333     Marcus     Hardy           Santa Quitéria
# 54176     -117.263916     Travis    Morris                 Wildomar
# 54177      -83.953419     Taylor     Grant  Bangor Charter Township
# 54178      104.548272    Jeffery     Salas                  Taizhou
#
#                     state name_dist_center  order_id
# 0               Occitanie       Memphis TN      7309
# 1                  Oregon       Memphis TN     86841
# 2      Castilla-La Mancha       Memphis TN     95584
# 3                Amazonas        Mobile AL     61063
# 4        Distrito Federal        Mobile AL     85780
# ...                   ...              ...       ...
# 54174       Île-de-France   New Orleans LA     22851
# 54175               Ceará   New Orleans LA     26002
# 54176          California   New Orleans LA     27662
# 54177            Michigan   New Orleans LA     60679
# 54178             Sichuan   New Orleans LA    103633
#
# [54179 rows x 13 columns]

# %%
# Create map

## Initialize map
map_center = [relevant_data['latitude_dist_center'].mean(), relevant_data['longitude_dist_center'].mean()]
map = folium.Map(location=map_center, zoom_start=4)

## Add distribution centers and user locations
for _, row in relevant_data.head(10).iterrows():
    folium.Marker(
        location=[row['latitude_dist_center'], row['longitude_dist_center']],
        popup=f"Distribution Center: {row['name_dist_center']}",
        icon=folium.Icon(color='blue', icon='industry', prefix='fa')
    ).add_to(map)

    folium.Marker(
        location=[row['latitude_user'], row['longitude_user']],
        popup=f"User: {row['first_name']} {row['last_name']}",
        icon=folium.Icon(color='green', icon='user', prefix='fa')
    ).add_to(map)

    folium.PolyLine(
        locations=[(row['latitude_dist_center'], row['longitude_dist_center']),
                   (row['latitude_user'], row['longitude_user'])],
        popup=f"User in: {row['city']}, {row['state']}\n\n Shipped from: {row['name_dist_center']}",
        color="grey",
        weight=2,
        opacity=0.7
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8703a1e18efa8781dd22260cd428394 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8703a1e18efa8781dd22260cd428394&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8703a1e18efa8781dd22260cd428394 = L.map(
#                 &quot;map_f8703a1e18efa8781dd22260cd428394&quot;,
#                 {
#                     center: [34.9486652042372, -88.58984045297234],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86604f8d3875b67c8b346ec869f08084 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_86604f8d3875b67c8b346ec869f08084.addTo(map_f8703a1e18efa8781dd22260cd428394);
#
#
#             var marker_1b0709f5a3023181a6b8e7abf6af3ecd = L.marker(
#                 [35.1174, -89.9711],
#                 {}
#             ).addTo(map_f8703a1e18efa8781dd22260cd428394);
#
#
#             var icon_9379b898b7c302bc59e5c0490d497e88 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;industry&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1b0709f5a3023181a6b8e7abf6af3ecd.setIcon(icon_9379b898b7c302bc59e5c0490d497e88);
#
#
#         var popup_49bd0c7c918ac17c0cf632bd087c95fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e0c329be60522d6167c763b383061275 = $(`&lt;div id=&quot;html_e0c329be60522d6167c763b383061275&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Distribution Center: Memphis TN&lt;/div&gt;`)[0];
#                 popup_49bd0c7c918ac17c0cf632bd087c95fd.setContent(html_e0c329be60522d6167c763b383061275);
#
#
#
#         marker_1b0709f5a3023181a6b8e7abf6af3ecd.bindPopup(popup_49bd0c7c918ac17c0cf632bd087c95fd)
#         ;
#
#
#
#
#             var marker_0fb52e53537dcf2ee7c9d83a6fdb0624 = L.marker(
#                 [42.70234107, 2.898221046],
#                 {}
#             ).addTo(map_f8703a1e18efa8781dd22260cd428394);
#
#
#             var icon_6790359007560907a20eaee5a8f9ab42 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;user&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0fb52e53537dcf2ee7c9d83a6fdb0624.setIcon(icon_6790359007560907a20eaee5a8f9ab42);
#
#
#         var popup_8c67a78fb9f7dbb65135a976e617529f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ae6e3de278ee67f293fb87a38bec7d0 = $(`&lt;div id=&quot;html_4ae6e3de278ee67f293fb87a38bec7d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User: Debra Wiley&lt;/div&gt;`)[0];
#                 popup_8c67a78fb9f7dbb65135a976e617529f.setContent(html_4ae6e3de278ee67f293fb87a38bec7d0);
#
#
#
#         marker_0fb52e53537dcf2ee7c9d83a6fdb0624.bindPopup(popup_8c67a78fb9f7dbb65135a976e617529f)
#         ;
#
#
#
#
#             var poly_line_da67198ba60144c871111b395f2e89bb = L.polyline(
#                 [[35.1174, -89.9711], [42.70234107, 2.898221046]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_f8703a1e18efa8781dd22260cd428394);
#
#
#         var popup_cea893b20203b08b1bf4422095beb159 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b0d501d50aa3a7de1c767ac03152469 = $(`&lt;div id=&quot;html_5b0d501d50aa3a7de1c767ac03152469&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User in: Perpignan, Occitanie   Shipped from: Memphis TN&lt;/div&gt;`)[0];
#                 popup_cea893b20203b08b1bf4422095beb159.setContent(html_5b0d501d50aa3a7de1c767ac03152469);
#
#
#
#         poly_line_da67198ba60144c871111b395f2e89bb.bindPopup(popup_cea893b20203b08b1bf4422095beb159)
#         ;
#
#
#
#
#             var marker_506cb761cbd3f7007ce043c32c971e61 = L.marker(
#                 [35.1174, -89.9711],
#                 {}
#             ).addTo(map_f8703a1e18efa8781dd22260cd428394);
#
#
#             var icon_1c6672a6625729803e4751ee6cd465da = L.AwesomeMarkers.icon(
#                 {&qu
